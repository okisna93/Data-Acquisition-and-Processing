# %% [markdown]
# ## Ismet Okan Celik CWID: 10472265

# %% [markdown]
# ## Question-1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.arima_model import ARIMA

Data=pd.read_csv('EE627A_HW2_Q2.csv',header=None)
Data
# Out:
#           0
# 0    0.8512
# 1   -2.0698
# 2    0.8185
# 3   -1.0678
# 4    2.3753
# ..      ...
# 295 -1.2904
# 296  1.1051
# 297  1.1782
# 298 -0.0994
# 299 -3.0491
#
# [300 rows x 1 columns]

# %%
sns.lineplot(data=Data)
plt.xlabel('Data Points')
plt.ylabel('Value')
plt.show()

# %%
plot_acf(Data, lags=25);
plot_pacf(Data, lags=25);

# %% [markdown]
# #### a) False --> Because as we can see on the ACF graph AR(1) correlated with the AR(2)
# #### b) False --> Because as we can see on the graph of ACF coefficent cliff after l>=2

# %% [markdown]
# ## Question-2

# %%
Data2=pd.read_csv('EE627A_HW2_Q3.csv',header=None)
Data2
# Out:
#            0
# 0     1.0374
# 1     1.0372
# 2     1.0372
# 3     1.0370
# 4     1.0369
# ...      ...
# 1245  1.0515
# 1246  1.0511
# 1247  1.0515
# 1248  1.0534
# 1249  1.0534
#
# [1250 rows x 1 columns]

# %%
Data3 = sns.lineplot(data=Data2)
Data3.set_title('DATA')
Data3.set(xlabel='Count', ylabel='Value')
plt.show()

# %%
#Taking Difference in order to Make Stationary
difference=Data2.diff(periods=1)
difference=difference[1:]
difference.head()
# Out:
#         0
# 1 -0.0002
# 2  0.0000
# 3 -0.0002
# 4 -0.0001
# 5  0.0001

# %%
#Oylesine Deneme
sns.lineplot(data=difference)
plt.xlabel('Number of Data')
plt.ylabel('Values')
plt.show()

# %%
#Oylesine Deneme
plot_acf(difference, lags=25);
plot_pacf(difference, lags=25);

# %%
Model_Q3_1= ARIMA(Data2, order=(0, 0, 4))
Model_Q3_1_fit =Model_Q3_1.fit()
Model_Q3_1_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                      0   No. Observations:                 1250
# Model:                     ARMA(0, 4)   Log Likelihood                6203.723
# Method:                       css-mle   S.D. of innovations              0.002
# Date:                Sun, 13 Feb 2022   AIC                         -12395.446
# Time:                        08:55:46   BIC                         -12364.661
# Sample:                             0   HQIC                        -12383.873
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.0216      0.000   2424.604      0.000       1.021       1.022
# ma.L1.0        2.3114      0.023     99.576      0.000       2.266       2.357
# ma.L2.0        2.8043      0.038     74.070      0.000       2.730       2.879
# ma.L3.0        2.0063      0.031     65.242      0.000       1.946       2.067
# ma.L4.0        0.7221      0.017     42.448      0.000       0.689       0.755
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1           -0.3773           -0.9893j            1.0588           -0.3080
# MA.2           -0.3773           +0.9893j            1.0588            0.3080
# MA.3           -1.0120           -0.4597j            1.1115           -0.4321
# MA.4           -1.0120           +0.4597j            1.1115            0.4321
# -----------------------------------------------------------------------------
# """

# %%
q2_residuals = pd.DataFrame(Model_Q3_1_fit.resid)
plot_acf(q2_residuals, title='q2 residuals acf')
plt.show()

# %%
plot_pacf(q2_residuals, title='q2 residuals pacf', zero=False)
plt.show()

# %%
Model_Q3_1= ARIMA(Data2, order=(3, 1, 4))
Model_Q3_1_fit =Model_Q3_1.fit()
Model_Q3_1_fit.summary()
# Out:
# C:\Users\okanc\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8052/1670415296.py in <module>
# ----> 1 Model_Q3_1= ARIMA(Data2, order=(3, 1, 4))
#       2 Model_Q3_1_fit =Model_Q3_1.fit()
#       3 Model_Q3_1_fit.summary()
#
# ~\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py in __new__(cls, endog, order, exog, dates, freq, missing)
#    1069         else:
#    1070             mod = super(ARIMA, cls).__new__(cls)
# -> 1071             mod.__init__(endog, order, exog, dates, freq, missing)
#    1072             return mod
#    1073
#
# ~\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py in __init__(self, endog, order, exog, dates, freq, missing)
#    1097             self.exog = self.exog[d:]
#    1098         if d == 1:
# -> 1099             self.data.ynames = 'D.' + self.endog_names
#    1100         else:
#    1101             self.data.ynames = 'D{0:d}.'.format(d) + self.endog_names
#
# TypeError: can only concatenate str (not "int") to str
