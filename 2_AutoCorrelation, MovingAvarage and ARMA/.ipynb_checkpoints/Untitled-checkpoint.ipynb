# %%
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.arima_model import ARIMA

Data=pd.read_csv('EE627A_HW2_Q2.csv',header=None)
Data
# Out:
#           0
# 0    0.8512
# 1   -2.0698
# 2    0.8185
# 3   -1.0678
# 4    2.3753
# ..      ...
# 295 -1.2904
# 296  1.1051
# 297  1.1782
# 298 -0.0994
# 299 -3.0491
#
# [300 rows x 1 columns]

# %%
Data = sns.lineplot(data=Data)
Data.set_title('DATA')
Data.set(xlabel='Count', ylabel='Value')
plt.show()

# %%
plot_acf(Data, lags=25);
plot_pacf(Data, lags=25);

# %% [markdown]
# ## Problem-1
# a) True --> Because as we can see on the ACF graph r~0 when l>=2 that's why xt is uncorrelated with xt-1
# a) False --> Because as we can see on the graph of ACF coefficent cliff after l>=2
